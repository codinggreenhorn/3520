# %%
import pandas as pd
import statsmodels.api as sm

# Load data (file contains non-UTF8 player name characters)
df = pd.read_csv('../data/playoff_36_salary.csv', encoding='latin1')

# Keep only players who logged more than 10 minutes
df['MPG'] = pd.to_numeric(df['MPG'], errors='coerce')
#df = df[df['MP'] > 10].copy()

# Independent variables requested
x_cols = [
    'GS', 'MPG', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PTS',
    'Awards', 'Pos_C', 'Pos_PF', 'Pos_SF', 'Pos_SG'
]

y_col = 'Salary'

# Keep only needed columns and coerce to numeric
model_df = df[x_cols + [y_col]].copy()
model_df = model_df.apply(pd.to_numeric, errors='coerce').dropna()

# Convert salary to millions
model_df['Salary_millions'] = model_df[y_col] / 1_000_000

X = sm.add_constant(model_df[x_cols])
y = model_df['Salary_millions']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Salary_millions   R-squared:                       0.758
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                     26.07
# Date:                Mon, 13 Apr 2026   Prob (F-statistic):           1.79e-27
# Time:                        18:06:52   Log-Likelihood:                -419.60
# No. Observations:                 122   AIC:                             867.2
# Df Residuals:                     108   BIC:                             906.5
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -11.1039      3.967     -2.799      0.006     -18.968      -3.240
# GS             0.4042      0.128      3.148      0.002       0.150       0.659
# MPG            0.4888      0.100      4.865      0.000       0.290       0.688
# TRB            0.4987      0.370      1.348      0.180      -0.234       1.232
# AST            0.2490      0.543      0.459      0.647      -0.827       1.325
# STL           -0.6828      1.321     -0.517      0.606      -3.301       1.935
# BLK            0.7735      1.302      0.594      0.554      -1.807       3.354
# TOV            1.3072      0.747      1.751      0.083      -0.173       2.787
# PTS            0.7142      0.169      4.223      0.000       0.379       1.049
# Awards        10.3303      2.119      4.875      0.000       6.130      14.531
# Pos_C         -0.1561      3.783     -0.041      0.967      -7.655       7.343
# Pos_PF         1.8257      3.031      0.602      0.548      -4.183       7.834
# Pos_SF         2.0254      3.085      0.657      0.513      -4.089       8.139
# Pos_SG        -1.7979      2.623     -0.685      0.495      -6.997       3.402
# ==============================================================================
# Omnibus:                        0.080   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.961   Jarque-Bera (JB):                0.001
# Skew:                           0.006   Prob(JB):                         1.00
# Kurtosis:                       2.994   Cond. No.                         279.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import pandas as pd
import statsmodels.api as sm

# Load data (file contains non-UTF8 player name characters)
df = pd.read_csv('../data/playoff_36_salary.csv', encoding='latin1')

# Keep only players who logged more than 10 minutes
df['MPG'] = pd.to_numeric(df['MPG'], errors='coerce')
df = df[df['MPG'] > 10].copy()

# Independent variables requested
x_cols = [
    'GS', 'MPG', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PTS',
    'Awards', 'Pos_C', 'Pos_PF', 'Pos_SF', 'Pos_SG'
]

y_col = 'Salary'

# Keep only needed columns and coerce to numeric
model_df = df[x_cols + [y_col]].copy()
model_df = model_df.apply(pd.to_numeric, errors='coerce').dropna()

# Convert salary to millions
model_df['Salary_millions'] = model_df[y_col] / 1_000_000

X = sm.add_constant(model_df[x_cols])
y = model_df['Salary_millions']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Salary_millions   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.705
# Method:                 Least Squares   F-statistic:                     21.25
# Date:                Mon, 13 Apr 2026   Prob (F-statistic):           7.63e-23
# Time:                        18:08:25   Log-Likelihood:                -384.96
# No. Observations:                 111   AIC:                             797.9
# Df Residuals:                      97   BIC:                             835.9
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -12.7859      4.489     -2.848      0.005     -21.695      -3.877
# GS             0.3923      0.137      2.857      0.005       0.120       0.665
# MPG            0.5419      0.128      4.223      0.000       0.287       0.797
# TRB            0.5655      0.418      1.353      0.179      -0.264       1.395
# AST           -0.1442      0.642     -0.225      0.823      -1.417       1.129
# STL           -0.1882      1.525     -0.123      0.902      -3.216       2.839
# BLK            0.7990      1.480      0.540      0.591      -2.139       3.737
# TOV            1.8383      1.131      1.625      0.107      -0.406       4.083
# PTS            0.7404      0.187      3.957      0.000       0.369       1.112
# Awards         9.7911      2.224      4.403      0.000       5.378      14.204
# Pos_C         -1.8409      4.237     -0.434      0.665     -10.251       6.569
# Pos_PF         0.5981      3.385      0.177      0.860      -6.121       7.317
# Pos_SF         1.2875      3.264      0.394      0.694      -5.191       7.766
# Pos_SG        -2.4131      2.759     -0.875      0.384      -7.888       3.062
# ==============================================================================
# Omnibus:                        0.012   Durbin-Watson:                   2.108
# Prob(Omnibus):                  0.994   Jarque-Bera (JB):                0.039
# Skew:                          -0.012   Prob(JB):                        0.981
# Kurtosis:                       2.911   Cond. No.                         287.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Without mpg

# %%
import pandas as pd
import statsmodels.api as sm

# Load data (file contains non-UTF8 player name characters)
df = pd.read_csv('../data/playoff_36_salary.csv', encoding='latin1')

# Keep only players who logged more than 10 minutes
df['MPG'] = pd.to_numeric(df['MPG'], errors='coerce')
df = df[df['MPG'] > 10].copy()

# Independent variables requested
x_cols = [
    'GS', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PTS',
    'Awards', 'Pos_C', 'Pos_PF', 'Pos_SF', 'Pos_SG'
]

y_col = 'Salary'

# Keep only needed columns and coerce to numeric
model_df = df[x_cols + [y_col]].copy()
model_df = model_df.apply(pd.to_numeric, errors='coerce').dropna()

# Convert salary to millions
model_df['Salary_millions'] = model_df[y_col] / 1_000_000

X = sm.add_constant(model_df[x_cols])
y = model_df['Salary_millions']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Salary_millions   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     18.38
# Date:                Mon, 13 Apr 2026   Prob (F-statistic):           4.34e-20
# Time:                        18:28:16   Log-Likelihood:                -394.33
# No. Observations:                 111   AIC:                             814.7
# Df Residuals:                      98   BIC:                             849.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.5836      4.248     -0.844      0.401     -12.013       4.846
# GS             0.6616      0.132      5.026      0.000       0.400       0.923
# TRB            0.6141      0.452      1.358      0.178      -0.283       1.512
# AST            0.3914      0.681      0.575      0.567      -0.959       1.742
# STL           -1.3738      1.623     -0.846      0.399      -4.595       1.847
# BLK            0.3597      1.598      0.225      0.822      -2.812       3.532
# TOV            1.7419      1.224      1.423      0.158      -0.687       4.171
# PTS            0.9352      0.196      4.764      0.000       0.546       1.325
# Awards        11.1389      2.382      4.676      0.000       6.412      15.866
# Pos_C         -1.1662      4.583     -0.254      0.800     -10.262       7.929
# Pos_PF         2.2718      3.639      0.624      0.534      -4.950       9.494
# Pos_SF         2.2805      3.524      0.647      0.519      -4.713       9.274
# Pos_SG        -1.7064      2.981     -0.572      0.568      -7.622       4.209
# ==============================================================================
# Omnibus:                        1.028   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.598   Jarque-Bera (JB):                0.845
# Skew:                           0.214   Prob(JB):                        0.655
# Kurtosis:                       3.003   Cond. No.                         160.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
